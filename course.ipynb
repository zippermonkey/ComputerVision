# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
import cv2

# %%
img = cv2.imread("./images/lena512color.tiff")

# %%
cv2.imwrite("./images/lena.jpg",img)
# Out:
# True

# %%
imgpath = "./images/"

# %%
img = cv2.imread(imgpath+"lena.jpg")

# %%
cv2.imshow("image",img)
cv2.waitKey(1000)
# Out:
# -1

# %%
img
# Out:
# array([[[128, 139, 223],
#         [126, 137, 221],
#         [127, 137, 224],
#         ...,
#         [122, 147, 233],
#         [108, 131, 223],
#         [ 81, 101, 196]],
#
#        [[128, 139, 223],
#         [126, 137, 221],
#         [127, 137, 224],
#         ...,
#         [119, 143, 231],
#         [108, 128, 223],
#         [ 82, 101, 200]],
#
#        [[127, 138, 222],
#         [127, 137, 224],
#         [125, 138, 224],
#         ...,
#         [123, 147, 237],
#         [110, 129, 228],
#         [ 85, 100, 203]],
#
#        ...,
#
#        [[ 54,  19,  83],
#         [ 56,  22,  86],
#         [ 59,  27,  92],
#         ...,
#         [ 82,  69, 177],
#         [ 81,  70, 180],
#         [ 72,  63, 173]],
#
#        [[ 55,  20,  84],
#         [ 57,  23,  87],
#         [ 63,  31,  96],
#         ...,
#         [ 82,  68, 180],
#         [ 84,  71, 186],
#         [ 81,  71, 185]],
#
#        [[ 55,  20,  84],
#         [ 57,  23,  87],
#         [ 63,  31,  96],
# ...

# %%
print(cv2.IMREAD_GRAYSCALE)
# Out:
# 0

# %%
img = cv2.imread(imgpath+"lena.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
print(img.shape)
# Out:
# (512, 512, 3)

# %%
print(np.min(img),np.max(img))
# Out:
# 0 255

# %%
#imgOfThree = np.concatenate((np.expand_dims(img, axis=2), np.expand_dims(img, axis=2), np.expand_dims(img, axis=2)), axis=-1)

plt.imshow(img)

# %%
noise = np.random.normal(0,0.1**0.5,img.shape)

# %%
plt.imshow(img_noise)

# %%
# Out:
# float64

# %%
img_f = img/255
print(img_f.dtype)
img_noise = img_f+noise
img_noise = np.clip(img_noise,0,1)
# Out:
# float64

# %%
img_gaussian = cv2.GaussianBlur(img_noise,(3,3),0.1)
plt.imshow(img_gaussian)
